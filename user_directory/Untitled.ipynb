# %%
ls
# Out:
# Untitled.ipynb           data/                    tensorflowvisu.py
# __init__.py              iris_test.csv            tensorflowvisu.pyc
# __pycache__/             iris_training.csv        test/
# boston housing/          libs/                    test_0531/
# boston.py*               lzfxxx/                  test_folder/
# boston_predict.csv*      mnist_1.0_softmax.py     test_user/
# boston_test.csv*         tensor.py                user_0607/
# boston_train.csv*        tensorflowvisu.mplstyle

# %%
cd data
# Out:
# /Users/darthvader/goldersgreen/user_directory/data

# %%
cd ..
# Out:
# /Users/darthvader/goldersgreen/user_directory

# %%
cd test
# Out:
# /Users/darthvader/goldersgreen/user_directory/test

# %%
notebook nbagg

# %%
# %run mnist_1.0_softmax.py
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
# %run mnist_1.0_softmax.py
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz
# start_animation
# 0: accuracy:0.11 loss:230.259
#
# 0: epoch accuracy:0.098 loss:230.26
#
# 50: accuracy:0.81 loss:59.7133
#
# 100: accuracy:0.92 loss:33.1166
#
# 150: accuracy:0.87 loss:40.2714
#
# 200: accuracy:0.94 loss:31.8514
#
# 200: epoch accuracy:0.9005 loss:34.436
#
# 250: accuracy:0.83 loss:52.9365
#
# 300: accuracy:0.93 loss:25.7219
#
# 350: accuracy:0.89 loss:31.5012
#
# 400: accuracy:0.87 loss:44.2979
#
# 400: epoch accuracy:0.911 loss:31.5401
#
# 450: accuracy:0.9 loss:33.6612
#
# 500: accuracy:0.95 loss:19.3787
#
# 550: accuracy:0.92 loss:47.876
#
# 600: accuracy:0.96 loss:25.3278
#
# 600: epoch accuracy:0.9162 loss:29.8806
#
# 650: accuracy:0.93 loss:36.2018
#
# 700: accuracy:0.89 loss:31.2137
#
# 750: accuracy:0.9 loss:36.9419
#
# 800: accuracy:0.9 loss:41.2967
#
# ...
