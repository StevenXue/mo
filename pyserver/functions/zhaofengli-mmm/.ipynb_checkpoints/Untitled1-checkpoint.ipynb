# %%
# %%capture output
import time
for i in range(0, 10):
    time.sleep(1)   
    print(i)

# %%
# %%capture output
# The output of code below this command would be captured
# and could be restored using 'output.show()'

# %%
print(1)
# Out:
# 1

# %%
for i, j in ((0,'q'),(8, 'p')):
    print(i, j)
# Out:
# 0 q
# 8 p
